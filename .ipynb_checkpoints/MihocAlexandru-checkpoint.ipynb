# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# ===== DATA LOADING =====
df = pd.read_csv('MergeConflictsDataset.csv', sep=';')
print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (26973, 37)

# %%
# ===== 1. DATA PREPROCESSING =====

# Drop rows with missing values
df = df.dropna()

# Print new shape to confirm
print(f"New dataset shape after dropping missing rows: {df.shape}")
# Out:
# New dataset shape after dropping missing rows: (26972, 37)

# %%
df.head()
# Out:
#                                      commit  \
# 0  efc0bcd1d6199448c323549fdc45310750b48c85
# 1  287b9b838b6b6b212ef538aa537aef76110ee111
# 2  e7478680c0db825239ea9628967728c8577bb5c2
# 3  0c65b30a8fd3a7db40163fcb9b0004cb7487c0ff
# 4  419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
#
#                                     parent1  \
# 0  fb9f2a65cabba5a924b89a45793914066471b2ab
# 1  72fd7d81c9c7e28af8740f5a1b210a803290383d
# 2  36977963caa2896ad9a4a92b2bdcd85189beccb1
# 3  419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
# 4  7899f565d3461ed287e61662c8d399aafcac9e42
#
#                                     parent2  \
# 0  5ee7c7c750e9ecffaea12f97d5b05b2445e7c007
# 1  fb9f2a65cabba5a924b89a45793914066471b2ab
# 2  bc230857adc3a9763bc7d89793d826463c857c00
# 3  877c43f8242b88447d0234400c6e9b5c7586b558
# 4  5e68e04e310c4f57a19d4cfa6be1e0ba3a8801d6
#
#                                    ancestor  is pr  added lines  \
# 0  fb9f2a65cabba5a924b89a45793914066471b2ab      1            5
# ...

# %%
print("Target variable distribution:")
print(df['conflict'].value_counts(normalize=True))
# Out:
# Target variable distribution:
# conflict
# 0    0.945573
# 1    0.054427
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='conflict', data=df)
plt.title('Conflict vs No Conflict')
plt.show()

# %% [markdown]
# The dataset seems to be **highly imbalanced** with only about 5.44% of the samples representing merge conflicts (class 1) while 94.56% represent non-conflict merges (class 0).
#
# This means:
# - it will prove more difficult to train models as they may be biased
# - should apply stratification during test train split to maintain this class distribution in both sets
# - justifies using metrics such as F1 score and PR-AUC as they are more appropiiate for an imbalanced classification rather than accuracy

# %%
df
# Out:
#                                          commit  \
# 0      efc0bcd1d6199448c323549fdc45310750b48c85
# 1      287b9b838b6b6b212ef538aa537aef76110ee111
# 2      e7478680c0db825239ea9628967728c8577bb5c2
# 3      0c65b30a8fd3a7db40163fcb9b0004cb7487c0ff
# 4      419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
# ...                                         ...
# 26968  c52216c411e4d7d9ef7845926f471f49f48b3ea5
# 26969  8bf4fb99b439379ed99f0a4fc761fa65ca31d8ba
# 26970  a27a50f87f61d871ddb1aeed6993b132fd657ea6
# 26971  ddddae9b5f9537cb06d2c4872184fa25d9f3ca77
# 26972  542ff7fe4297d73a39664b468962ab681e4bea91
#
#                                         parent1  \
# 0      fb9f2a65cabba5a924b89a45793914066471b2ab
# 1      72fd7d81c9c7e28af8740f5a1b210a803290383d
# 2      36977963caa2896ad9a4a92b2bdcd85189beccb1
# 3      419e6d2d9fb91f2d9cdbdd1161a6c7ecc329363f
# 4      7899f565d3461ed287e61662c8d399aafcac9e42
# ...                                         ...
# ...

# %%
# Remove ID columns as they are not useful for prediction
id_cols = ['commit', 'parent1', 'parent2', 'ancestor']
df_clean = df.drop(columns=id_cols)
df = df_clean

# %% [markdown]
# Feature-target split, we break the dataset into input features (X) and output label (y) where X contains all predictor variables that will be used to forecast the occurrence of merge conflicts, and y contains the binary outcome variable (1 for conflict, 0 for no conflict).

# %%
X = df_clean.drop('conflict', axis=1)
X.head()
# Out:
#    is pr  added lines  deleted lines  devs parent1  devs parent2  time  \
# 0      1            5              0             0             1    23
# 1      0         1166          11267             1             2   371
# 2      1            0              0             0             1    22
# 3      1            0              0             2             1    24
# 4      0            0              0             1             2     2
#
#    nr files  added files  deleted files  renamed files  ...  update  add  \
# 0         0            0              0              0  ...       3    0
# 1         3            7            199              2  ...       1    0
# 2         0            0              0              0  ...       0    0
# 3         1            0              0              0  ...       0    0
# 4         1            0              0              0  ...       0    0
#
#    remove  use  delete  change  messages_min  messages_max  messages_mean  \
# ...

# %%
# Check if all features are numeric after the data cleanup, if they are all numeric encoding is not needed
if df.drop(columns=['conflict']).applymap(np.isreal).all().all():
    print("✅ All features are numeric. No encoding is required before training.")
else:
    print("⚠️ Some features are non-numeric. Encoding is needed.")
# Out:
# ✅ All features are numeric. No encoding is required before training.

# %%
y = df_clean['conflict']
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 26968    0
# 26969    0
# 26970    0
# 26971    0
# 26972    0
# Name: conflict, Length: 26972, dtype: int64

# %%
# Scale features as the data is unbalanced, we won't actually use all X'es from here so after we extract the features I will scale those
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 0.53453522, -0.04728659, -0.02436358, ..., -0.44335517,
#         -0.85027386, -1.21939375],
#        [-1.8707841 ,  0.08334547,  1.0717378 , ...,  0.13785337,
#         -0.2719818 , -0.36877705],
#        [ 0.53453522, -0.04784917, -0.02436358, ..., -0.96867828,
#         -1.28467015, -1.27017684],
#        ...,
#        [ 0.53453522, -0.04773665, -0.0242663 , ..., -0.52159479,
#         -0.91019059, -0.88930369],
#        [ 0.53453522, -0.04773665, -0.0242663 , ..., -1.08044915,
#         -1.5343232 , -1.52409227],
#        [ 0.53453522, -0.04773665, -0.0242663 , ..., -0.91279284,
#         -1.15984363, -1.14321912]], shape=(26972, 32))

# %% [markdown]
# **PERFORMANCE METRICS SELECTION**
#
# **Precision**
# Measures the proportion of predicted conflicts that were actually true conflicts.
# Important when false positives (incorrectly predicting a conflict) are costly.
#
# **Recall**
# Measures the proportion of actual conflicts that were correctly identified by the model.
# Important when false negatives (missing a real conflict) are costly.
#
# **F1-Score**
# The harmonic mean of precision and recall.
# It balances the two, especially useful when classes are imbalanced.
#
# **PR-AUC (Precision-Recall AUC)**
# The area under the Precision-Recall curve.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    precision_recall_curve, 
    auc
)
import numpy as np

def evaluate_model(model, X_test, y_test, model_name, save_plots=False):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, 'predict_proba') else None

    print(f"\n{model_name} Performance:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # normalize

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues',
                xticklabels=['No Conflict', 'Conflict'],
                yticklabels=['No Conflict', 'Conflict'],
                cbar=False)
    plt.xlabel('Predicted', fontsize=12)
    plt.ylabel('Actual', fontsize=12)
    plt.title(f'Normalized Confusion Matrix - {model_name}', fontsize=14)
    
    if save_plots:
        plt.savefig(f"{model_name.replace(' ', '_')}_confusion_matrix.png", bbox_inches='tight')
    plt.show()
    plt.close()
    
    # Precision-Recall Curve
    if y_pred_proba is not None:
        precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
        pr_auc = auc(recall, precision)
        print(f"PR-AUC: {pr_auc:.4f}")

        plt.figure(figsize=(7, 5))
        plt.plot(recall, precision, color='navy', lw=2, label=f'PR curve (AUC = {pr_auc:.4f})')
        plt.fill_between(recall, precision, alpha=0.3, color='blue')
        plt.xlabel('Recall', fontsize=12)
        plt.ylabel('Precision', fontsize=12)
        plt.title(f'Precision-Recall Curve - {model_name}', fontsize=14)
        plt.legend(loc='lower left')
        plt.grid(alpha=0.3)
        
        if save_plots:
            plt.savefig(f"{model_name.replace(' ', '_')}_pr_curve.png", bbox_inches='tight')
        plt.show()
        plt.close()

    return {
        'model': model,
        'classification_report': classification_report(y_test, y_pred, output_dict=True)
    }

# %% [markdown]
# **Feature Selection**
#
# 1. Correlation with Target Variable
# We first analyze the correlation between each feature and the target variable (conflict).
# Correlation measures the linear relationship between a feature and the target, this can be seen via the heatmap that Seaborn provides
#
# 2. Random Forest Feature Importances
# I will train a Random Forest Classifier and retrieve its feature importances as they are ensembles of decision trees that naturally provide a ranking of feature importance.

# %%
# 1. Correlation with Target Variable

plt.figure(figsize=(16, 12))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=False)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
# 2. Random Forest Feature Importances
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(14, 6))
plt.title("Feature Importances (Random Forest)")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), np.array(df.columns)[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# The features selected are thus: **nr_files**, **is_pr**, **nr_commits2**

# %%
print(df.columns.tolist())
# Out:
# ['is pr', 'added lines', 'deleted lines', 'devs parent1', 'devs parent2', 'time', 'nr files', 'added files', 'deleted files', 'renamed files', 'copied files', 'modified files', 'nr commits1', 'nr commits2', 'density1', 'density2', 'fix', 'bug', 'feature', 'improve', 'document', 'refactor', 'update', 'add', 'remove', 'use', 'delete', 'change', 'messages_min', 'messages_max', 'messages_mean', 'messages_median', 'conflict']

# %% [markdown]
# I will make **smaller dataframes** extracting only the columns we have identified as important features

# %%
X_selected = df[['nr files', 'is pr', 'nr commits2']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected)

X_scaled_df = pd.DataFrame(X_scaled, columns=['nr_files', 'is pr', 'nr_commits2'])

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled_df, y, test_size=0.2, random_state=42, stratify=y
)

print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (21577, 3), Test shape: (5395, 3)

# %% [markdown]
# Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

tree = DecisionTreeClassifier(random_state=42)

param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10]
}

grid_tree = GridSearchCV(tree, param_grid, scoring='f1', cv=5)
grid_tree.fit(X_train, y_train)

best_tree = grid_tree.best_estimator_

print("Best parameters:", grid_tree.best_params_)
print("Best cross-validation F1 score:", grid_tree.best_score_)

results_tree = evaluate_model(best_tree, X_test, y_test, model_name="Decision Tree", save_plots=True)
# Out:
# Best parameters: {'max_depth': 4, 'min_samples_split': 2}
# Best cross-validation F1 score: 0.6631871896213658
#
# Decision Tree Performance:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      5101
#            1       0.68      0.62      0.65       294
#
#     accuracy                           0.96      5395
#    macro avg       0.83      0.80      0.81      5395
# weighted avg       0.96      0.96      0.96      5395
# PR-AUC: 0.6782

# %%
plt.figure(figsize=(20, 10))  
plot_tree(best_tree, 
          feature_names=['nr_files', 'is_pr', 'nr_commits2'], 
          class_names=['No Conflict', 'Conflict'], 
          filled=True, rounded=True, fontsize=10)
plt.title("Visualization of the Best Decision Tree", fontsize=16)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()

nb_model.fit(X_train, y_train)

results_nb = evaluate_model(nb_model, X_test, y_test, model_name="Naive Bayes", save_plots=True)
# Out:
# Naive Bayes Performance:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      5101
#            1       0.61      0.32      0.42       294
#
#     accuracy                           0.95      5395
#    macro avg       0.79      0.66      0.70      5395
# weighted avg       0.94      0.95      0.94      5395
# PR-AUC: 0.5643

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [4, 6, 8, 10],
    'min_samples_split': [2, 5, 10]
}

grid_rf = GridSearchCV(rf, param_grid_rf, scoring='f1', cv=5)
grid_rf.fit(X_train, y_train)

best_rf = grid_rf.best_estimator_

print("Best Random Forest parameters:", grid_rf.best_params_)
print("Best Random Forest cross-validation F1 score:", grid_rf.best_score_)

results_rf = evaluate_model(best_rf, X_test, y_test, model_name="Random Forest", save_plots=True)
# Out:
# Best Random Forest parameters: {'max_depth': 8, 'min_samples_split': 5, 'n_estimators': 200}
# Best Random Forest cross-validation F1 score: 0.649267652657932
#
# Random Forest Performance:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      5101
#            1       0.67      0.57      0.62       294
#
#     accuracy                           0.96      5395
#    macro avg       0.82      0.78      0.80      5395
# weighted avg       0.96      0.96      0.96      5395
# PR-AUC: 0.6789

# %% [markdown]
# ### Model Performances Overview
#
# | Model          | Test F1-Score | Test PR-AUC | Notes                                           |
# |----------------|---------------|-------------|-------------------------------------------------|
# | Decision Tree  | 0.65          | 0.6782      | Good balance, slight overfitting avoided by depth control |
# | Naive Bayes    | 0.42          | 0.5643      | Very simple model, struggles on complex patterns |
# | Random Forest  | 0.62          | 0.6789      | More robust, ensemble of trees improves generalization |
